# %%
import argparse
import pathlib
import random

import numpy as np
import pandas as pd
from copairs import map
from copairs.matching import assign_reference_index

# check if in a jupyter notebook
try:
    cfg = get_ipython().config
    in_notebook = True
except NameError:
    in_notebook = False
import warnings

import pycytominer.aggregate
import tqdm

# Suppress all RuntimeWarnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

#

# %%
input_dir = pathlib.Path("../results/mAP_cell_percentages/").resolve(strict=True)
output_file = pathlib.Path("../results/mAP_cell_percentages.parquet").resolve()
# get a list of all files in the directory
df = pd.concat([pd.read_parquet(file) for file in list(input_dir.glob("*"))])
df.to_parquet(output_file)
df.head()
# Out:
#   Metadata_Time   Metadata_treatment  Metadata_reference_index  \
# 0            00        Ab1-42 0.4 uM                        -1
# 1            00         Ab1-42 10 uM                        -1
# 2            00          Ab1-42 2 uM                        -1
# 3            00  Flagellin 0.1 ug/ml                        -1
# 4            00    Flagellin 1 ug/ml                        -1
#
#    mean_average_precision       indices   p_value  corrected_p_value  below_p  \
# 0                0.716667  [63, 64, 65]  0.299861           0.471210    False
# 1                0.719444  [52, 54, 56]  0.299861           0.471210    False
# 2                0.525000  [58, 60, 62]  0.499343           0.549277    False
# 3                0.352778  [39, 41, 43]  0.899782           0.899782    False
# 4                0.555556  [33, 35, 37]  0.499343           0.549277    False
#
#    below_corrected_p  -log10(p-value)  percentage_of_cells    seed  shuffle
# 0              False         0.326786                  0.8  577882     True
# 1              False         0.326786                  0.8  577882     True
# 2              False         0.260209                  0.8  577882     True
# 3              False         0.045863                  0.8  577882     True
# 4              False         0.260209                  0.8  577882     True

# %%
import pathlib

import pandas as pd

# %%
file_paths = pathlib.Path("../results_of_memory_profiling").resolve().glob("*")
output_file_path = pathlib.Path(
    "../results_of_memory_profiling/concatenated_results.parquet"
).resolve()
file_paths = sorted(file_paths)

# %%
list_of_dfs = [
    pd.read_parquet(file_path)
    for file_path in file_paths
    if not file_path == output_file_path
]
concated_df = pd.concat(list_of_dfs, ignore_index=True)
concated_df.to_parquet(output_file_path)
concated_df.head()
# Out:
#    num_of_features  num_of_cells_per_well  num_of_wells  \
# 0             1000                   1000          1000
# 1             1000                   1000           100
# 2             1000                   1000             1
# 3             1000                    100          1000
# 4             1000                    100           100
#
#    num_of_features_retained  percent_of_features_retained      rss_MB  \
# 0                      1001                         100.0   62.406250
# 1                      1001                         100.0  770.605469
# 2                      1001                         100.0   29.089844
# 3                      1001                         100.0  771.007812
# 4                      1001                         100.0   82.769531
#
#        vms_MB  shared_MB  text_MB  lib_MB     data_MB  dirty_MB    total_MB  \
# 0  278.164062     2.4375      0.0     0.0  276.894531       0.0   62.406250
# 1  982.425781     2.4375      0.0     0.0  981.156250       0.0  770.605469
# 2  240.835938     2.6250      0.0     0.0  239.566406       0.0   29.089844
# 3  982.390625     2.6250      0.0     0.0  981.121094       0.0  771.007812
# 4  294.777344     2.6250      0.0     0.0  293.507812       0.0   82.769531
#
#    elapsed_time
# 0    183.545341
# 1      8.050165
# 2      0.278377
# 3      8.122283
# 4      0.819083

# %%
concated_df["total_MB"].max()
# Out:
# np.float64(6910.0859375)
